# %%
import xgboost as xgb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
combine = pd.read_csv('Draft_Combine.csv')

# %%
combine.tail(10)
# Out:
#                  PLAYER  YEAR    POS  HEIGHT  WEIGHT    BMI  BODY FAT  \
# 1469   Santangelo, Matt  2000     PG   72.00   177.0  24.00       NaN
# 1470       Scales, Alex  2000  PG/SG   74.25   184.5  23.53       NaN
# 1471     Shabazz, Karim  2000      C   83.50   224.0  22.59       NaN
# 1472     Sheppard, Nick  2000   PF/C   81.50   273.0  28.89       NaN
# 1473      Smith, Jabari  2000   PF/C   81.75   240.5  25.30       NaN
# 1474        Smith, Mike  2000     SF   78.50   198.0  22.59       NaN
# 1475  Stephens, Jarrett  2000     PF   77.25   258.0  30.39       NaN
# 1476   Thornton, Bootsy  2000     SG   75.50   194.5  23.99       NaN
# 1477      Walls, Jaquay  2000     PG   73.25   165.5  21.68       NaN
# 1478    Watkins, Jameel  2000   PF/C   81.50   244.5  25.88       NaN
#
#       STANDING REACH  WINGSPAN  HAND LENGTH  HAND WIDTH  STANDING VERTICAL  \
# 1469            94.0     75.00          NaN         NaN               33.5
# 1470            97.5     81.00          NaN         NaN               38.5
# 1471           111.5     87.00          NaN         NaN               24.5
# 1472           107.5     83.00          NaN         NaN               23.5
# 1473           109.5     86.50          NaN         NaN               24.5
# 1474           103.0     80.50          NaN         NaN               33.0
# 1475           103.0     81.25          NaN         NaN               27.0
# 1476           101.5     78.50          NaN         NaN               26.5
# 1477            96.5     74.50          NaN         NaN               28.5
# 1478           110.0     90.00          NaN         NaN               28.0
#
#       VERTICAL LEAP  LANE AGILITY  SHUTTLE RUN  THREE QUARTER SPRINT  \
# 1469           43.0         10.66          NaN                  3.06
# 1470           42.5         10.98          NaN                  3.21
# 1471           28.0         12.72          NaN                  3.36
# 1472           25.5         12.14          NaN                  3.52
# 1473           30.0         12.45          NaN                  3.43
# 1474           21.0         11.32          NaN                  3.22
# 1475           29.0         11.98          NaN                  3.46
# 1476           31.0         12.08          NaN                  3.33
# 1477           35.5         10.75          NaN                  3.23
# 1478           30.5         12.38          NaN                  3.45
#
#       BENCH PRESS    BAR  PAN    PBH    PDT
# 1469         12.0  1.042  NaN  127.5  137.0
# 1470         10.0  1.091  NaN  136.0  140.0
# 1471          2.0  1.042  NaN  136.0  139.5
# 1472         18.0  1.018  NaN  131.0  133.0
# 1473         15.0  1.058  NaN  134.0  139.5
# 1474         12.0  1.025  NaN  136.0  124.0
# 1475         13.0  1.052  NaN  130.0  132.0
# 1476          7.0  1.040  NaN  128.0  132.5
# 1477          0.0  1.017  NaN  125.0  132.0
# 1478         11.0  1.104  NaN  138.0  140.5

# %%
combine.shape
# Out:
# (1479, 21)

# %%
combine.isna().sum()
# Out:
# PLAYER                     0
# YEAR                       0
# POS                        0
# HEIGHT                     4
# WEIGHT                     6
# BMI                        6
# BODY FAT                 234
# STANDING REACH             5
# WINGSPAN                   3
# HAND LENGTH              735
# HAND WIDTH               735
# STANDING VERTICAL        171
# VERTICAL LEAP            171
# LANE AGILITY             180
# SHUTTLE RUN             1014
# THREE QUARTER SPRINT     179
# BENCH PRESS              404
# BAR                        4
# PAN                      735
# PBH                      172
# PDT                      172
# dtype: int64

# %% [markdown]
# # dropped shuttle run (1014 missing values)

# %%
combine = combine.drop(['SHUTTLE RUN'], axis=1)

# %% [markdown]
# # drop body fat (we will use bmi which has no missing values)

# %%
combine = combine.drop(['BODY FAT'], axis=1)

# %% [markdown]
# # dropped rows with missing height and weight values (only 6)

# %%
combine = combine[combine['HEIGHT'].notna()]
combine = combine[combine['WEIGHT'].notna()]
combine.shape
# Out:
# (1473, 19)

# %% [markdown]
# # Used linear regression with height as the predictor to predict hand length and width

# %%
combine.plot.scatter(x='HEIGHT', y='HAND LENGTH')
# Out:
# <AxesSubplot:xlabel='HEIGHT', ylabel='HAND LENGTH'>

# %%
combine.plot.scatter(x='HEIGHT', y='HAND WIDTH')
# Out:
# <AxesSubplot:xlabel='HEIGHT', ylabel='HAND WIDTH'>

# %%
test1 = combine[combine['HAND LENGTH'].isnull()]

# %%
train1 = combine[combine['HAND LENGTH'].notna()]

# %%
x_train1 = train1['HEIGHT'].values.reshape(-1, 1)

# %%
y_train1 = train1['HAND LENGTH']

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()

# %%
reg.fit(x_train1, y_train1)
# Out:
# LinearRegression()

# %%
x_test1 = test1['HEIGHT'].values.reshape(-1,1)

# %%
y_pred1 = reg.predict(x_test1)

# %%
test1['HAND LENGTH'] = y_pred1
# Out:
# <ipython-input-97-51959410ca17>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test1['HAND LENGTH'] = y_pred1

# %%
y_train2 = train1['HAND WIDTH']

# %%
reg2 = LinearRegression()

# %%
reg2.fit(x_train1, y_train2)
# Out:
# LinearRegression()

# %%
y_pred2 = reg2.predict(x_test1)

# %%
test1['HAND WIDTH'] = y_pred2
# Out:
# <ipython-input-104-2a9a2eb47af3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test1['HAND WIDTH'] = y_pred2

# %%
combine2 = pd.concat([train1, test1])

# %%
combine2
# Out:
#                     PLAYER  YEAR   POS  HEIGHT  WEIGHT    BMI  STANDING REACH  \
# 0            Agbaji, Ochai  2022    SG   76.50   216.8  26.04           104.0
# 1     Baldwin Jr., Patrick  2022    SF   81.25   230.8  24.58           110.5
# 2         Barlow, Dominick  2022    PF   80.75   221.0  23.83           108.5
# 3        Beauchamp, MarJon  2022    SG   77.25   196.6  23.16           106.0
# 4             Besson, Hugo  2022    SG   76.50   180.4  21.67           102.0
# ...                    ...   ...   ...     ...     ...    ...             ...
# 1474           Smith, Mike  2000    SF   78.50   198.0  22.59           103.0
# 1475     Stephens, Jarrett  2000    PF   77.25   258.0  30.39           103.0
# 1476      Thornton, Bootsy  2000    SG   75.50   194.5  23.99           101.5
# 1477         Walls, Jaquay  2000    PG   73.25   165.5  21.68            96.5
# 1478       Watkins, Jameel  2000  PF/C   81.50   244.5  25.88           110.0
#
#       WINGSPAN  HAND LENGTH  HAND WIDTH  STANDING VERTICAL  VERTICAL LEAP  \
# 0        82.25     8.750000    9.500000               32.0           39.0
# 1        85.75     8.750000    9.500000               23.5           26.5
# 2        87.00     9.000000   10.500000               28.5           34.0
# 3        84.75     9.000000    9.000000                NaN            NaN
# 4        77.50     7.500000    8.500000               24.5           31.5
# ...        ...          ...         ...                ...            ...
# 1474     80.50     8.807104    9.517017               33.0           21.0
# 1475     81.25     8.696462    9.406991               27.0           29.0
# 1476     78.50     8.541564    9.252955               26.5           31.0
# 1477     74.50     8.342409    9.054908               28.5           35.5
# 1478     90.00     9.072643    9.781079               28.0           30.5
#
#       LANE AGILITY  THREE QUARTER SPRINT  BENCH PRESS    BAR   PAN    PBH  \
# 0            10.77                  3.13          NaN  1.075  83.1  136.0
# 1            12.25                  3.45          NaN  1.055  83.1  134.0
# 2            11.29                  3.33          NaN  1.077  94.5  137.0
# 3              NaN                   NaN          NaN  1.097  81.0    NaN
# 4            11.36                  3.40          NaN  1.013  63.8  126.5
# ...            ...                   ...          ...    ...   ...    ...
# 1474         11.32                  3.22         12.0  1.025   NaN  136.0
# 1475         11.98                  3.46         13.0  1.052   NaN  130.0
# 1476         12.08                  3.33          7.0  1.040   NaN  128.0
# 1477         10.75                  3.23          0.0  1.017   NaN  125.0
# 1478         12.38                  3.45         11.0  1.104   NaN  138.0
#
#         PDT
# 0     143.0
# 1     137.0
# 2     142.5
# 3       NaN
# 4     133.5
# ...     ...
# 1474  124.0
# 1475  132.0
# 1476  132.5
# 1477  132.0
# 1478  140.5
#
# [1473 rows x 19 columns]

# %% [markdown]
# # used new hand width and lengths values to find PAN values (hand length times hand width)

# %%
combine2['PAN'] = combine2['HAND LENGTH'] * combine2['HAND WIDTH']

# %%
combine2
# Out:
#                     PLAYER  YEAR   POS  HEIGHT  WEIGHT    BMI  STANDING REACH  \
# 0            Agbaji, Ochai  2022    SG   76.50   216.8  26.04           104.0
# 1     Baldwin Jr., Patrick  2022    SF   81.25   230.8  24.58           110.5
# 2         Barlow, Dominick  2022    PF   80.75   221.0  23.83           108.5
# 3        Beauchamp, MarJon  2022    SG   77.25   196.6  23.16           106.0
# 4             Besson, Hugo  2022    SG   76.50   180.4  21.67           102.0
# ...                    ...   ...   ...     ...     ...    ...             ...
# 1474           Smith, Mike  2000    SF   78.50   198.0  22.59           103.0
# 1475     Stephens, Jarrett  2000    PF   77.25   258.0  30.39           103.0
# 1476      Thornton, Bootsy  2000    SG   75.50   194.5  23.99           101.5
# 1477         Walls, Jaquay  2000    PG   73.25   165.5  21.68            96.5
# 1478       Watkins, Jameel  2000  PF/C   81.50   244.5  25.88           110.0
#
#       WINGSPAN  HAND LENGTH  HAND WIDTH  STANDING VERTICAL  VERTICAL LEAP  \
# 0        82.25     8.750000    9.500000               32.0           39.0
# 1        85.75     8.750000    9.500000               23.5           26.5
# 2        87.00     9.000000   10.500000               28.5           34.0
# 3        84.75     9.000000    9.000000                NaN            NaN
# 4        77.50     7.500000    8.500000               24.5           31.5
# ...        ...          ...         ...                ...            ...
# 1474     80.50     8.807104    9.517017               33.0           21.0
# 1475     81.25     8.696462    9.406991               27.0           29.0
# 1476     78.50     8.541564    9.252955               26.5           31.0
# 1477     74.50     8.342409    9.054908               28.5           35.5
# 1478     90.00     9.072643    9.781079               28.0           30.5
#
#       LANE AGILITY  THREE QUARTER SPRINT  BENCH PRESS    BAR        PAN  \
# 0            10.77                  3.13          NaN  1.075  83.125000
# 1            12.25                  3.45          NaN  1.055  83.125000
# 2            11.29                  3.33          NaN  1.077  94.500000
# 3              NaN                   NaN          NaN  1.097  81.000000
# 4            11.36                  3.40          NaN  1.013  63.750000
# ...            ...                   ...          ...    ...        ...
# 1474         11.32                  3.22         12.0  1.025  83.817353
# 1475         11.98                  3.46         13.0  1.052  81.807538
# 1476         12.08                  3.33          7.0  1.040  79.034699
# 1477         10.75                  3.23          0.0  1.017  75.539741
# 1478         12.38                  3.45         11.0  1.104  88.740244
#
#         PBH    PDT
# 0     136.0  143.0
# 1     134.0  137.0
# 2     137.0  142.5
# 3       NaN    NaN
# 4     126.5  133.5
# ...     ...    ...
# 1474  136.0  124.0
# 1475  130.0  132.0
# 1476  128.0  132.5
# 1477  125.0  132.0
# 1478  138.0  140.5
#
# [1473 rows x 19 columns]

# %%
combine2.isna().sum()
# Out:
# PLAYER                    0
# YEAR                      0
# POS                       0
# HEIGHT                    0
# WEIGHT                    0
# BMI                       0
# STANDING REACH            1
# WINGSPAN                  0
# HAND LENGTH               0
# HAND WIDTH                0
# STANDING VERTICAL       166
# VERTICAL LEAP           166
# LANE AGILITY            175
# THREE QUARTER SPRINT    174
# BENCH PRESS             398
# BAR                       0
# PAN                       0
# PBH                     166
# PDT                     166
# dtype: int64

# %%
combine2 = combine2[combine2['STANDING REACH'].notna()]

# %%
combine2.shape
# Out:
# (1472, 19)

# %%
combine3 = combine2[combine2['STANDING VERTICAL'].notna()]

# %%
combine3 = combine3[combine3['LANE AGILITY'].notna()]

# %%
combine3 = combine3[combine3['THREE QUARTER SPRINT'].notna()]

# %%
combine3.isna().sum()
combine3.shape
# Out:
# (1289, 19)

# %% [markdown]
# # use linear regression based on weight to determine bench press

# %%
test2 = combine3[combine3['BENCH PRESS'].isnull()]

# %%
train2 = combine3[combine3['BENCH PRESS'].notna()]

# %%
x_train2 = train2['WEIGHT'].values.reshape(-1, 1)

# %%
y_train2 = train2['BENCH PRESS']

# %%
reg3 = LinearRegression()
reg3.fit(x_train2, y_train2)
# Out:
# LinearRegression()

# %%
x_test2 = test2['WEIGHT'].values.reshape(-1,1)
y_pred2 = reg3.predict(x_test2)
# Out:
# array([10.46554113, 11.60180913, 10.80642153,  7.51124434,  8.67997714,
#         9.84870994,  9.19941394,  7.02427235, 10.10842834,  8.22546994,
#        16.65008551,  8.71244194,  8.43649114, 10.44930873,  6.45613835,
#        12.07254873,  8.76113914, 12.38096433, 11.76413313,  9.80001274,
#        11.03367513, 10.80642153, 11.30962593, 11.97515433, 12.59198553,
#        10.43307633,  7.57617394,  9.99480154, 10.14089314,  7.73849794,
#         6.81325115, 10.49800593,  8.74490674,  7.47877954,  8.51765314,
#        12.70561233, 14.03666912,  7.41384995,  7.67356834,  6.27758195,
#         8.79360394,  9.71885074, 11.66673873, 10.22205514,  9.37797034,
#         8.06314594,  9.83247754,  9.84870994, 12.07254873, 14.34508472,
#         6.00163115, 10.46554113, 11.16353433, 11.55311193,  9.62145634,
#         9.62145634, 10.30321713,  8.64751234,  9.39420274,  9.34550554,
#        12.57575313, 14.66973272,  9.50782954, 10.51423833,  9.88117474,
#        12.83547153, 11.73166833,  6.58599755,  9.32927314,  7.86835714,
#         6.95934275,  9.62145634, 11.03367513,  7.41384995,  8.09561074,
#        11.71543593, 12.33226713,  8.71244194, 12.18617553,  9.58899154,
#        11.17976673,  7.98198394,  9.62145634,  7.52747674,  8.20923754,
#        13.03026032,  8.87476594, 12.54328833,  9.63768874, 13.17635192,
#         9.26434354,  6.03409595,  9.34550554, 10.64409753,  8.84230114,
#        12.13747833,  9.49159714,  8.29039954,  8.16054034,  8.46895594,
#        11.19599913,  7.54370914,  9.16694914, 13.93115852, 10.14089314,
#        11.24469633, 10.89569973,  7.90082194, 10.90381593,  8.98839274,
#         9.34550554, 10.23828753,  8.53388554,  8.82606874,  8.56635034,
#         6.73208915,  9.68638594, 11.94268953,  8.77737154, 11.82094653,
#        10.17335794,  9.42666754, 12.90040113, 10.96874553, 13.12765472,
#         7.94951914, 10.66032993, 12.47835873,  7.34892035,  9.23187874,
#        11.37455553,  6.66715955, 10.85511873, 14.49929252, 13.37114072,
#         9.50782954,  8.77737154, 11.55311193, 12.12124593,  9.52406194,
#         9.62145634,  8.35532914,  9.63768874,  8.93969554,  8.04691354,
#         8.22546994,  7.83589234,  9.16694914,  9.29680834, 11.45571753,
#        10.10842834,  9.24811114,  9.63768874, 11.47194993, 11.08237233,
#        10.96874553, 11.78036553,  8.61504754, 10.61163273, 10.54670313,
#         7.25152595, 10.12466074,  9.47536474,  8.85853354,  9.39420274,
#         8.59881514,  9.80001274, 12.64068273,  9.80001274,  9.99480154,
#        10.40061153,  7.54370914, 11.60180913, 12.77054193,  6.16395515,
#         7.78719514, 10.74149193, 10.57916793,  9.06955474, 11.26092873,
#        13.51723232,  4.97898995, 10.27075233,  9.94610434,  9.91363954,
#        10.54670313, 12.57575313, 11.86152753, 10.17335794, 12.52705593,
#         9.81624514,  9.52406194, 13.49288372, 13.35490832,  9.81624514,
#        11.63427393,  9.25622734,  7.83589234,  8.51765314,  7.96575154,
#         7.99010014,  8.42025874,  8.77737154,  9.86494234, 10.60351653,
#         7.60052254,  8.80172014, 10.57105173, 10.73337573, 11.43948513,
#        10.31944953,  9.76754794, 10.59540033,  8.93969554, 13.32244352,
#         7.55182534,  8.48518834, 11.34209073,  8.74490674, 10.56293553,
#         7.43008234,  7.08920195, 13.71202112, 11.21223153,  7.91705434,
#        11.89399233, 13.13577092, 10.02726634, 12.24298893, 11.30962593,
#         5.85553955,  9.66203734, 14.19899312,  8.04691354, 12.92474973,
#        10.74149193,  9.18318154, 12.90040113,  9.84870994,  8.45272354,
#         8.97216034, 12.41342913,  8.03068114,  9.42666754,  8.40402634,
#        10.49800593, 16.55269111, 11.26092873,  9.39420274,  8.74490674,
#        10.95251313, 13.72825352, 13.89057752, 15.59497952, 11.29339353,
#        11.45571753,  7.96575154,  8.93969554,  9.26434354,  8.93969554,
#         8.85853354,  9.91363954, 10.23828753, 10.56293553, 10.07596354,
#        12.59198553,  9.91363954])

# %%
test2['BENCH PRESS'] = np.round(y_pred2)
# Out:
# <ipython-input-129-13868cdbf203>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test2['BENCH PRESS'] = np.round(y_pred2)

# %%
test2
# Out:
#                     PLAYER  YEAR    POS  HEIGHT  WEIGHT    BMI  \
# 0            Agbaji, Ochai  2022     SG   76.50   216.8  26.04
# 1     Baldwin Jr., Patrick  2022     SF   81.25   230.8  24.58
# 2         Barlow, Dominick  2022     PF   80.75   221.0  23.83
# 4             Besson, Hugo  2022     SG   76.50   180.4  21.67
# 5          Branham, Malaki  2022     SG   76.00   194.8  23.71
# ...                    ...   ...    ...     ...     ...    ...
# 1217        Jones, Dahntay  2003  SG/SF   76.75   214.0  25.54
# 1295           Jones, Fred  2002     SG   74.25   218.0  27.80
# 1332       Williams, Frank  2002     PG   73.50   212.0  27.59
# 1418        Brezec, Primoz  2000      C   84.75   243.0  23.78
# 1445          Jaric, Marko  2000  SG/SF   78.50   210.0  23.96
#
#       STANDING REACH  WINGSPAN  HAND LENGTH  HAND WIDTH  STANDING VERTICAL  \
# 0              104.0     82.25     8.750000    9.500000               32.0
# 1              110.5     85.75     8.750000    9.500000               23.5
# 2              108.5     87.00     9.000000   10.500000               28.5
# 4              102.0     77.50     7.500000    8.500000               24.5
# 5              102.5     82.00     8.500000    9.800000               29.0
# ...              ...       ...          ...         ...                ...
# 1217           102.5     81.00     8.652205    9.362981               30.0
# 1295           100.0     84.00     8.430922    9.142929               33.5
# 1332           100.5     80.00     8.364537    9.076913               26.0
# 1418           110.0     86.00     9.360312   10.067147               26.0
# 1445           104.0     81.00     8.807104    9.517017               27.5
#
#       VERTICAL LEAP  LANE AGILITY  THREE QUARTER SPRINT  BENCH PRESS    BAR  \
# 0              39.0         10.77                  3.13         10.0  1.075
# 1              26.5         12.25                  3.45         12.0  1.055
# 2              34.0         11.29                  3.33         11.0  1.077
# 4              31.5         11.36                  3.40          8.0  1.013
# 5              35.0         11.38                  3.17          9.0  1.079
# ...             ...           ...                   ...          ...    ...
# 1217           39.5         10.91                  3.11         10.0  1.055
# 1295           37.5         11.12                  3.13         11.0  1.131
# 1332           31.0         11.73                  3.29         10.0  1.088
# 1418           29.5         11.53                  3.55         13.0  1.015
# 1445           33.0         11.32                  3.28         10.0  1.032
#
#             PAN    PBH    PDT
# 0     83.125000  136.0  143.0
# 1     83.125000  134.0  137.0
# 2     94.500000  137.0  142.5
# 4     63.750000  126.5  133.5
# 5     83.300000  131.5  137.5
# ...         ...    ...    ...
# 1217  81.010429  132.5  142.0
# 1295  77.083317  133.5  137.5
# 1332  75.924174  126.5  131.5
# 1418  94.231632  136.0  139.5
# 1445  83.817353  131.5  137.0
#
# [267 rows x 19 columns]

# %%
train2
# Out:
#                  PLAYER  YEAR   POS  HEIGHT  WEIGHT    BMI  STANDING REACH  \
# 169      Bazley, Darius  2019    PF   79.75   208.4  23.04           107.0
# 171        Bone, Jordan  2019    SG   73.50   179.0  23.29            95.0
# 172     Bowen II, Brian  2019    SF   78.25   200.0  22.96           103.0
# 173          Bowman, Ky  2019    PG   73.00   181.2  23.90            98.0
# 174   Brazdeikis, Ignas  2019    SF   77.75   220.8  25.68           102.0
# ...                 ...   ...   ...     ...     ...    ...             ...
# 1474        Smith, Mike  2000    SF   78.50   198.0  22.59           103.0
# 1475  Stephens, Jarrett  2000    PF   77.25   258.0  30.39           103.0
# 1476   Thornton, Bootsy  2000    SG   75.50   194.5  23.99           101.5
# 1477      Walls, Jaquay  2000    PG   73.25   165.5  21.68            96.5
# 1478    Watkins, Jameel  2000  PF/C   81.50   244.5  25.88           110.0
#
#       WINGSPAN  HAND LENGTH  HAND WIDTH  STANDING VERTICAL  VERTICAL LEAP  \
# 169      84.00     9.000000    9.800000               30.5           37.0
# 171      75.25     7.500000    9.300000               36.0           42.5
# 172      82.00     8.500000    9.800000               32.0           35.5
# 173      79.00     8.250000    9.000000               27.5           33.0
# 174      81.25     8.750000    9.500000               31.0           36.5
# ...        ...          ...         ...                ...            ...
# 1474     80.50     8.807104    9.517017               33.0           21.0
# 1475     81.25     8.696462    9.406991               27.0           29.0
# 1476     78.50     8.541564    9.252955               26.5           31.0
# 1477     74.50     8.342409    9.054908               28.5           35.5
# 1478     90.00     9.072643    9.781079               28.0           30.5
#
#       LANE AGILITY  THREE QUARTER SPRINT  BENCH PRESS    BAR        PAN  \
# 169          11.09                  3.27          4.0  1.053  88.200000
# 171           9.97                  3.08          7.0  1.024  69.750000
# 172          10.98                  3.26          1.0  1.048  83.300000
# 173          11.11                  3.26          4.0  1.082  74.250000
# 174          11.06                  3.36         13.0  1.045  83.125000
# ...            ...                   ...          ...    ...        ...
# 1474         11.32                  3.22         12.0  1.025  83.817353
# 1475         11.98                  3.46         13.0  1.052  81.807538
# 1476         12.08                  3.33          7.0  1.040  79.034699
# 1477         10.75                  3.23          0.0  1.017  75.539741
# 1478         12.38                  3.45         11.0  1.104  88.740244
#
#         PBH    PDT
# 169   137.5  144.0
# 171   131.0  137.5
# 172   135.0  138.5
# 173   125.5  131.0
# 174   133.0  138.5
# ...     ...    ...
# 1474  136.0  124.0
# 1475  130.0  132.0
# 1476  128.0  132.5
# 1477  125.0  132.0
# 1478  138.0  140.5
#
# [1022 rows x 19 columns]

# %%
combine4 = pd.concat([train2, test2])

# %%
combine4.isna().sum()
# Out:
# PLAYER                  0
# YEAR                    0
# POS                     0
# HEIGHT                  0
# WEIGHT                  0
# BMI                     0
# STANDING REACH          0
# WINGSPAN                0
# HAND LENGTH             0
# HAND WIDTH              0
# STANDING VERTICAL       0
# VERTICAL LEAP           0
# LANE AGILITY            0
# THREE QUARTER SPRINT    0
# BENCH PRESS             0
# BAR                     0
# PAN                     0
# PBH                     0
# PDT                     0
# dtype: int64
